# %%
import pandas as pd

# %%
df = pd.read_csv('flavors_of_cacao.csv')
df
# Out:
#      Company \n(Maker-if known)   Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                         Agua Grande  1876
# 1                      A. Morin                               Kpime  1676
# 2                      A. Morin                              Atsane  1676
# 3                      A. Morin                               Akata  1680
# 4                      A. Morin                              Quilla  1704
# 5                      A. Morin                            Carenero  1315
# 6                      A. Morin                                Cuba  1315
# 7                      A. Morin                        Sur del Lago  1315
# 8                      A. Morin                      Puerto Cabello  1319
# 9                      A. Morin                             Pablino  1319
# 10                     A. Morin                              Panama  1011
# 11                     A. Morin                          Madagascar  1011
# ...

# %%
df2 = pd.read_csv('C:/Users/Admin/Documents/Py_practice/Pandas/startup_funding.csv')
df2
# Out:
#        SNo         Date       StartupName   IndustryVertical  \
# 0        0   01/08/2017          TouchKin         Technology
# 1        1   02/08/2017           Ethinos         Technology
# 2        2   02/08/2017      Leverage Edu  Consumer Internet
# 3        3   02/08/2017              Zepo  Consumer Internet
# 4        4   02/08/2017      Click2Clinic  Consumer Internet
# 5        5   01/07/2017     Billion Loans  Consumer Internet
# 6        6   03/07/2017  Ecolibriumenergy         Technology
# 7        7   04/07/2017             Droom          eCommerce
# 8        8   05/07/2017         Jumbotail          eCommerce
# 9        9   05/07/2017            Moglix          eCommerce
# 10      10   05/07/2017        Timesaverz  Consumer Internet
# 11      11   06/07/2017            Minjar         Technology
# 12      12   06/07/2017       MyCity4kids  Consumer Internet
# 13      13   07/07/2017          Clip App  Consumer Internet
# ...

# %%
df3 = pd.read_excel('SampleData.xlsx','SalesOrders')
df3
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2016-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2016-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2016-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2016-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2016-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2016-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2016-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2016-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2016-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2016-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2016-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2016-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2016-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
print df.shape
print df2.shape
print df3.shape
# Out:
# (1795, 9)
# (2372, 10)
# (43, 7)

# %%
rows,columns = df3.shape #Tuple unpacking

# %%
rows
# Out:
# 43

# %%
columns
# Out:
# 7

# %%
df.head() #returns first 5 rows
# Out:
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# 4          2015            70%            France    3.50
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %%
df2.tail() #returns bottom 5 rows
# Out:
#        SNo        Date       StartupName IndustryVertical SubVertical  \
# 2367  2367  29/01/2015        Printvenue              NaN         NaN
# 2368  2368  29/01/2015          Graphene              NaN         NaN
# 2369  2369  30/01/2015    Mad Street Den              NaN         NaN
# 2370  2370  30/01/2015         Simplotel              NaN         NaN
# 2371  2371  31/01/2015  couponmachine.in              NaN         NaN
#
#      CityLocation                      InvestorsName  InvestmentType  \
# 2367          NaN        Asia Pacific Internet Group  Private Equity
# 2368          NaN                     KARSEMVEN Fund  Private Equity
# 2369          NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 2370          NaN                         MakeMyTrip  Private Equity
# 2371          NaN  UK based Group of Angel Investors    Seed Funding
#
#      AmountInUSD                            Remarks
# 2367   4,500,000                                NaN
# ...

# %%
df3.head(2)
# Out:
#    OrderDate   Region     Rep    Item  Units  Unit Cost   Total
# 0 2016-01-06     East   Jones  Pencil     95       1.99  189.05
# 1 2016-01-23  Central  Kivell  Binder     50      19.99  999.50

# %%
df.tail(2)
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name  REF  \
# 1793                     Zotter                      Kerala State  781
# 1794                     Zotter                Brazil, Mitzi Blue  486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 1793          2011            62%           Austria    3.25
# 1794          2010            65%           Austria    3.00
#
#      Broad Bean\nOrigin
# 1793              India
# 1794             Brazil

# %%
df3[3:10]
# Out:
#    OrderDate   Region       Rep    Item  Units  Unit Cost   Total
# 3 2016-02-26  Central      Gill     Pen     27      19.99  539.73
# 4 2016-03-15     West   Sorvino  Pencil     56       2.99  167.44
# 5 2016-04-01     East     Jones  Binder     60       4.99  299.40
# 6 2016-04-18  Central   Andrews  Pencil     75       1.99  149.25
# 7 2016-05-05  Central   Jardine  Pencil     90       4.99  449.10
# 8 2016-05-22     West  Thompson  Pencil     32       1.99   63.68
# 9 2016-06-08     East     Jones  Binder     60       8.99  539.40

# %%
df3[-2:]
# Out:
#     OrderDate   Region      Rep    Item  Units  Unit Cost    Total
# 41 2017-12-04  Central  Jardine  Binder     94      19.99  1879.06
# 42 2017-12-21  Central  Andrews  Binder     28       4.99   139.72

# %%
df.columns
# Out:
# Index([u'Company \n(Maker-if known)', u'Specific Bean Origin\nor Bar Name',
#        u'REF', u'Review\nDate', u'Cocoa\nPercent', u'Company\nLocation',
#        u'Rating', u'Bean\nType', u'Broad Bean\nOrigin'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index([u'SNo', u'Date', u'StartupName', u'IndustryVertical', u'SubVertical',
#        u'CityLocation', u'InvestorsName', u'InvestmentType', u'AmountInUSD',
#        u'Remarks'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index([u'OrderDate', u'Region', u'Rep', u'Item', u'Units', u'Unit Cost',
#        u'Total'],
#       dtype='object')

# %%
#df2.StartupName
df2['StartupName']
# Out:
# 0               TouchKin
# 1                Ethinos
# 2           Leverage Edu
# 3                   Zepo
# 4           Click2Clinic
# 5          Billion Loans
# 6       Ecolibriumenergy
# 7                  Droom
# 8              Jumbotail
# 9                 Moglix
# 10            Timesaverz
# 11                Minjar
# 12           MyCity4kids
# 13              Clip App
# 14           Upwardly.in
# 15            Autorox.co
# 16                Fabogo
# 17            Flickstree
# 18           Design Cafe
# 19              Innoviti
# 20              VDeliver
# 21              Bottr.me
# 22              Arcatron
# 23              QwikSpec
# 24               Chumbak
# 25               Increff
# 26                Vayana
# 27             MObiquest
# 28                 Ambee
# 29       Ideal Insurance
#               ...
# 2342             Refiral
# 2343        Ping Digital
# 2344     HealthyWorld.in
# 2345        Hostel Dunia
# 2346     Play your sport
# 2347             Yo Grad
# ...

# %%
type(df2['StartupName'])
# Out:
# pandas.core.series.Series

# %%
df2[['StartupName','CityLocation']].head()
# Out:
#     StartupName CityLocation
# 0      TouchKin    Bangalore
# 1       Ethinos       Mumbai
# 2  Leverage Edu    New Delhi
# 3          Zepo       Mumbai
# 4  Click2Clinic    Hyderabad

# %%
df['Rating']
# Out:
# 0       3.75
# 1       2.75
# 2       3.00
# 3       3.50
# 4       3.50
# 5       2.75
# 6       3.50
# 7       3.50
# 8       3.75
# 9       4.00
# 10      2.75
# 11      3.00
# 12      3.25
# 13      3.75
# 14      2.75
# 15      3.00
# 16      3.25
# 17      4.00
# 18      3.25
# 19      3.50
# 20      4.00
# 21      3.50
# 22      3.75
# 23      3.75
# 24      3.75
# 25      2.75
# 26      3.25
# 27      3.50
# 28      3.50
# 29      2.75
#         ...
# 1765    3.50
# 1766    3.00
# 1767    3.50
# 1768    2.75
# 1769    2.75
# 1770    3.00
# 1771    3.50
# 1772    3.50
# 1773    3.75
# 1774    3.25
# 1775    3.50
# 1776    3.50
# 1777    3.75
# 1778    2.75
# 1779    3.50
# 1780    3.50
# 1781    3.00
# 1782    3.50
# 1783    3.75
# 1784    3.00
# 1785    3.00
# 1786    3.25
# 1787    3.75
# 1788    3.25
# 1789    3.50
# 1790    3.75
# 1791    3.00
# 1792    3.50
# 1793    3.25
# 1794    3.00
# Name: Rating, Length: 1795, dtype: float64

# %%
df.Rating.max()
# Out:
# 5.0

# %%
df2.AmountInUSD
# Out:
# 0        1,300,000
# 1              NaN
# 2              NaN
# 3          500,000
# 4          850,000
# 5        1,000,000
# 6        2,600,000
# 7       20,000,000
# 8        8,500,000
# 9       12,000,000
# 10       1,000,000
# 11             NaN
# 12             NaN
# 13       1,000,000
# 14             NaN
# 15       3,000,000
# 16       2,250,000
# 17         464,000
# 18             NaN
# 19      18,500,000
# 20             NaN
# 21             NaN
# 22             NaN
# 23         540,000
# 24       1,700,000
# 25       2,000,000
# 26       4,000,000
# 27             NaN
# 28             NaN
# 29             NaN
#            ...
# 2342       330,000
# 2343           NaN
# 2344       200,000
# 2345        16,000
# 2346        16,000
# 2347        16,000
# 2348        16,000
# 2349        16,000
# 2350    11,000,000
# 2351           NaN
# 2352       200,000
# 2353    14,750,000
# 2354       325,000
# 2355           NaN
# 2356     3,250,000
# 2357       200,000
# ...

# %%
df2['AmountInUSD'].max()
# Out:
# '971,000'

# %%
df3['Unit Cost']
# Out:
# 0       1.99
# 1      19.99
# 2       4.99
# 3      19.99
# 4       2.99
# 5       4.99
# 6       1.99
# 7       4.99
# 8       1.99
# 9       8.99
# 10      4.99
# 11      1.99
# 12     19.99
# 13      4.99
# 14    125.00
# 15     15.99
# 16      8.99
# 17      8.99
# 18     19.99
# 19      4.99
# 20      1.29
# 21     15.99
# 22      8.99
# 23     15.00
# 24      4.99
# 25     19.99
# 26      4.99
# 27      1.99
# 28      4.99
# 29      1.29
# 30      8.99
# 31    125.00
# 32      4.99
# 33     12.49
# 34     23.95
# 35    275.00
# 36      1.29
# 37      1.99
# 38     19.99
# 39      1.29
# 40      4.99
# 41     19.99
# 42      4.99
# Name: Unit Cost, dtype: float64

# %%
df3['Unit Cost'].max()
# Out:
# 275.0

# %%
df3['Total'].max()
# Out:
# 1879.0599999999999

# %%
df.describe()
# Out:
#                REF  Review\nDate       Rating
# count  1795.000000   1795.000000  1795.000000
# mean   1035.904735   2012.325348     3.185933
# std     552.886365      2.927210     0.478062
# min       5.000000   2006.000000     1.000000
# 25%     576.000000   2010.000000     2.875000
# 50%    1069.000000   2013.000000     3.250000
# 75%    1502.000000   2015.000000     3.500000
# max    1952.000000   2017.000000     5.000000

# %%
df2.describe()
# Out:
#                SNo
# count  2372.000000
# mean   1185.500000
# std     684.881742
# min       0.000000
# 25%     592.750000
# 50%    1185.500000
# 75%    1778.250000
# max    2371.000000

# %%
df3.describe()
# Out:
#            Units   Unit Cost        Total
# count  43.000000   43.000000    43.000000
# mean   49.325581   20.308605   456.462326
# std    30.078248   47.345118   447.022104
# min     2.000000    1.290000     9.030000
# 25%    27.500000    3.990000   144.590000
# 50%    53.000000    4.990000   299.400000
# 75%    74.500000   17.990000   600.180000
# max    96.000000  275.000000  1879.060000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1795, step=1)

# %%
df2.reset_index()
# Out:
#              Date   SNo       StartupName   IndustryVertical  \
# 0      01/08/2017     0          TouchKin         Technology
# 1      02/08/2017     1           Ethinos         Technology
# 2      02/08/2017     2      Leverage Edu  Consumer Internet
# 3      02/08/2017     3              Zepo  Consumer Internet
# 4      02/08/2017     4      Click2Clinic  Consumer Internet
# 5      01/07/2017     5     Billion Loans  Consumer Internet
# 6      03/07/2017     6  Ecolibriumenergy         Technology
# 7      04/07/2017     7             Droom          eCommerce
# 8      05/07/2017     8         Jumbotail          eCommerce
# 9      05/07/2017     9            Moglix          eCommerce
# 10     05/07/2017    10        Timesaverz  Consumer Internet
# 11     06/07/2017    11            Minjar         Technology
# 12     06/07/2017    12       MyCity4kids  Consumer Internet
# 13     07/07/2017    13          Clip App  Consumer Internet
# ...

# %%
df2.set_index('StartupName',inplace=True)

# %%
df2.loc['Zepo']
# Out:
# SNo                                                                 3
# IndustryVertical                                    Consumer Internet
# SubVertical                                    DIY Ecommerce platform
# CityLocation                                                   Mumbai
# InvestorsName       Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...
# InvestmentType                                           Seed Funding
# AmountInUSD                                                   500,000
# Remarks                                                           NaN
# Name: Zepo, dtype: object

# %%
df2.reset_index()
# Out:
#            StartupName   SNo   IndustryVertical  \
# 0             TouchKin     0         Technology
# 1              Ethinos     1         Technology
# 2         Leverage Edu     2  Consumer Internet
# 3                 Zepo     3  Consumer Internet
# 4         Click2Clinic     4  Consumer Internet
# 5        Billion Loans     5  Consumer Internet
# 6     Ecolibriumenergy     6         Technology
# 7                Droom     7          eCommerce
# 8            Jumbotail     8          eCommerce
# 9               Moglix     9          eCommerce
# 10          Timesaverz    10  Consumer Internet
# 11              Minjar    11         Technology
# 12         MyCity4kids    12  Consumer Internet
# 13            Clip App    13  Consumer Internet
# 14         Upwardly.in    14  Consumer Internet
# 15          Autorox.co    15         Technology
# 16              Fabogo    16  Consumer Internet
# 17          Flickstree    17  Consumer Internet
# ...
